# %% [markdown]
# ---
# # Prerequisite: Mount your gdrive.

# %%
import os
from google.colab import drive

if not os.path.exists('/content/drive'):
  drive.mount('content/drive')

# %% [markdown]
# ---
# # Prerequisite: clone SRNet.

# %%
# %cd /content/drive/My Drive
# !git clone https://github.com/Niwhskal/SRNet.git

# %% [markdown]
# ---
# # Prerequisite: Install libraries.

# %%
# %cd SRNet
# %pip install -r requirements.txt

# %% [markdown]
# #download background image and synthesize the train dataset

# %%
# !chmod +x data_script.sh

# %%
# !./data_script.sh

# %% [markdown]
# #Training model

# %%
# %cd /content/drive/My Drive/SRNet
# !python train.py

# %% [markdown]
# #Makeing predictions

# %%
# !python predict.py --checkpoint '/content/drive/MyDrive/SRNet/logs/train_step-30000.model'
